# %% [markdown]
# ### Import all required libraries

# %%
import pandas as pd

# %% [markdown]
# ### Reading data from a dataset file into a pd dataframe

# %%
df_sample = pd.read_csv("My Sample Project\organizations-100.csv")

# %% [markdown]
# ### Show the type of data in the dataframe

# %%
df_sample.dtypes
# Out:
# Index                   int64
# Organization Id        object
# Name                   object
# Website                object
# Country                object
# Description            object
# Founded                 int64
# Industry               object
# Number of employees     int64
# dtype: object

# %% [markdown]
# ### Show the dataframe and data

# %%
df_sample
# Out:
#     Index  Organization Id                     Name
# 0       1  FAB0d41d5b5d22c              Ferrell LLC  \
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country
# 0               https://price.net/             Papua New Guinea  \
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %% [markdown]
# ### Show all rows and columns without collapsing any parts

# %%
# set_option('display.max_row', intValue)
# The intValue will determine how many rows or columns are allowed to be displayed
# For example if 4 is the intValue, then first two and last two rows will be displayed. Same applies to the Columns.
pd.set_option('display.max_row', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %%
df_sample
# Out:
#     Index  Organization Id                             Name
# 0       1  FAB0d41d5b5d22c                      Ferrell LLC  \
# 1       2  6A7EdDEA9FaDC52          Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                       Hester Ltd
# 3       4  2bFC1Be8a4ce42f                   Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                      Mayer Group
# 5       6  cC757116fe1C085                   Henry-Thompson
# 6       7  219233e8aFF1BC3                   Hansen-Everett
# 7       8  ccc93DCF81a31CD                    Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                         Carr Inc
# 9      10  738b5aDe6B1C6A5                       Gaines Inc
# 10     11  AE61b8Ffebbc476                       Kidd Group
# 11     12  eb3B7D06cCdD609                     Crane-Clarke
# 12     13  8D0c29189C9798B         Keller, Campos and Black
# 13     14  D2c91cc03CA394c                      Glover-Pope
# 14     15  C8AC1eaf9C036F4                   Pacheco-Spears
# ...

# %% [markdown]
# ### View the columns of the dataframe

# %%
df_sample.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %% [markdown]
# ### Create a subset of the data by removing un-needed columns

# %%
newSet = df_sample[['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
       'Founded', 'Number of employees']]
newSet.head(10) #Show only first 10 records
# newSet.tail(5) #Show only last 5 records
# Out:
#    Index  Organization Id                     Name
# 0      1  FAB0d41d5b5d22c              Ferrell LLC  \
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
# 5      6  cC757116fe1C085           Henry-Thompson
# 6      7  219233e8aFF1BC3           Hansen-Everett
# 7      8  ccc93DCF81a31CD            Mcintosh-Mora
# 8      9  0B4F93aA06ED03e                 Carr Inc
# 9     10  738b5aDe6B1C6A5               Gaines Inc
#
#                           Website                            Country
# 0              https://price.net/                   Papua New Guinea  \
# 1  http://www.hall-buchanan.info/                            Finland
# 2       http://sullivan-reed.com/                              China
# 3             https://becker.com/                       Turkmenistan
# ...

# %% [markdown]
# ### Check if there are any NaN values in the dataset

# %%
newSet.isna().sum()
# Out:
# Index                  0
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Description            0
# Founded                0
# Number of employees    0
# dtype: int64

# %% [markdown]
# ### If it has NaN values, then following can be used to show the specific records with those values

# %%
newSet[newSet['Name'].isna()] #Show records where 'Name' field has a NaN value
# Out:
# Empty DataFrame
# Columns: [Index, Organization Id, Name, Website, Country, Description, Founded, Number of employees]
# Index: []

# %% [markdown]
# ### Provide descriptive statistics and shape of the dataset.

# %%
newSet.describe()
#Note that below shown are all columns with numerical values
# Out:
#             Index      Founded  Number of employees
# count  100.000000   100.000000           100.000000
# mean    50.500000  1995.410000          4964.860000
# std     29.011492    15.744228          2850.859799
# min      1.000000  1970.000000           236.000000
# 25%     25.750000  1983.500000          2741.250000
# 50%     50.500000  1995.000000          4941.500000
# 75%     75.250000  2010.250000          7558.000000
# max    100.000000  2021.000000          9995.000000

# %%
newSet.hist(bins=20, figsize=(20,10))
#figsize values represent size of the graphs, with x = length(x) and y = height(y) => (x,y)
# Out:
# array([[<Axes: title={'center': 'Index'}>,
#         <Axes: title={'center': 'Founded'}>],
#        [<Axes: title={'center': 'Number of employees'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Show records where 'Founded' is equal to 2015

# %%
df_sample[df_sample['Founded']==2015]
# Out:
#    Index  Organization Id                     Name
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day  \
#
#                           Website  Country
# 1  http://www.hall-buchanan.info/  Finland  \
#
#                            Description  Founded                     Industry
# 1  User-centric system-worthy leverage     2015  Glass / Ceramics / Concrete  \
#
#    Number of employees
# 1                 4952
